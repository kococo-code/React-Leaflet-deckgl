# %%
import requests

country = "korea"
currency = "KRW"
locale = "ko-kr"
originplace = "ICN"
destinationplace = "CJU"
outboundpartialdate = "2020-05-13"
inboundpartialdate = "2020-05-20"

url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsedates/v1.0/%7B{country}%7D/%7B{currency}%7D/%7B{locale}%7D/%7B{originplace}%7D/%7B{destinationplace}%7D/%7B{outboundpartialdate}%7D/%7B{inboundpartialdate}%7D".format(
    country=country,
    currency=currency,
    locale = locale,
    originplace = originplace,
    destinationplace = destinationplace,
    outboundpartialdate = outboundpartialdate,
    inboundpartialdate =inboundpartialdate
    )

headers = {
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
    'x-rapidapi-key': "nI4ULc1zVemshtAJPRAg38HMX11op1CylKpjsnN95SHekKzZ3n"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"ValidationErrors":[{"ParameterName":"Country","ParameterValue":"{korea}","Message":"Incorrect value"},{"ParameterName":"Currency","ParameterValue":"{KRW}","Message":"Incorrect value"},{"ParameterName":"CountryId","Message":"The country specific is not a valid market"},{"ParameterName":"OutboundDate","ParameterValue":"{2020-05-13}","Message":"Incorrect date format"},{"ParameterName":"InboundDate","ParameterValue":"{2020-05-20}","Message":"Incorrect date format"}]}

# %%
response.json()
# Out:
# {'Routes': [],
#  'Quotes': [{'QuoteId': 1,
#    'MinPrice': 2849727.0,
#    'Direct': False,
#    'OutboundLeg': {'CarrierIds': [355],
#     'OriginId': 58542,
#     'DestinationId': 74763,
#     'DepartureDate': '2020-05-12T00:00:00'},
#    'QuoteDateTime': '2020-05-11T00:46:00'},
#   {'QuoteId': 2,
#    'MinPrice': 905503.0,
#    'Direct': False,
#    'OutboundLeg': {'CarrierIds': [1317],
#     'OriginId': 58542,
#     'DestinationId': 74763,
#     'DepartureDate': '2020-05-13T00:00:00'},
#    'QuoteDateTime': '2020-05-11T09:56:00'},
#   {'QuoteId': 3,
#    'MinPrice': 1753756.0,
#    'Direct': False,
#    'OutboundLeg': {'CarrierIds': [1530],
#     'OriginId': 58542,
#     'DestinationId': 74763,
#     'DepartureDate': '2020-05-14T00:00:00'},
#    'QuoteDateTime': '2020-05-11T08:06:00'},
#   {'QuoteId': 4,
#    'MinPrice': 921108.0,
#    'Direct': False,
#    'OutboundLeg': {'CarrierIds': [2037],
#     'OriginId': 58542,
#     'DestinationId': 74763,
# ...
